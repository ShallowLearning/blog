# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def test_func(y):
    return np.sin(y)

x = np.linspace(0,10,100)
y = test_func(x)
plt.plot(x,y)
plt.grid()
plt.show()
